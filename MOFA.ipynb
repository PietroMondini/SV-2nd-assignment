# %%
import pandas as pd

df = pd.read_csv('Clinical data/clinical_data.csv', index_col=0)

# Demographics
demographics = df[["age", "sex", "race", "participant_country", "bmi"]]

# Tumor characteristics
tumor = df[["tumor_site", "tumor_size_cm", "tumor_necrosis",
            "lymph_vascular_invasion", "perineural_invasion",
            "tumor_stage_pathological"]]

# Lifestyle
lifestyle = df[["alcohol_consumption", "tobacco_smoking_history"]]

# Outcomes
outcomes = df[["follow_up_days", "vital_status", "cause_of_death"]]

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

def preprocess(df_subset):
    # Separate categorical and numeric
    cat_cols = df_subset.select_dtypes(include=["object"]).columns
    num_cols = df_subset.select_dtypes(exclude=["object"]).columns
    
    # One-hot encode categorical
    enc = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
    cat_encoded = enc.fit_transform(df_subset[cat_cols]) if len(cat_cols) > 0 else None
    
    # Scale numeric
    scaler = StandardScaler()
    num_scaled = scaler.fit_transform(df_subset[num_cols]) if len(num_cols) > 0 else None
    
    # Combine
    import numpy as np
    if cat_encoded is not None and num_scaled is not None:
        return np.hstack([num_scaled, cat_encoded])
    elif cat_encoded is not None:
        return cat_encoded
    else:
        return num_scaled

# Apply preprocessing
views = {
    "demographics": preprocess(demographics),
    "tumor": preprocess(tumor),
    "lifestyle": preprocess(lifestyle),
    "outcomes": preprocess(outcomes)
}

# %%
from mofapy2.run.entry_point import entry_point
import pandas as pd
import numpy as np

# initialise the entry point
ent = entry_point()

D = [1000,1000] # Number of features per view
M = len(D)      # Number of views
K = 5           # Number of factors
N = [100,100]   # Number of samples per group
G = len(N)      # Number of groups

data_dt = pd.read_csv("http://ftp.ebi.ac.uk/pub/databases/mofa/getting_started/data.txt.gz", sep="\t")

ent.set_data_df(data_dt, likelihoods = ["gaussian","gaussian"])

ent.set_model_options(
    factors = 10, 
    spikeslab_weights = True, 
    ard_weights = True
)
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
#
#
# Loaded group='group_0' view='view_0' with N=100 samples and D=1000 features...
# Loaded group='group_0' view='view_1' with N=100 samples and D=1000 features...
# Loaded group='group_1' view='view_0' with N=100 samples and D=1000 features...
# Loaded group='group_1' view='view_1' with N=100 samples and D=1000 features...
#
#
# WARNING: 'ard_factors' in model_options should be set to True if using multiple groups unless you are using MEFISTO
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (view_0): gaussian
# - View 1 (view_1): gaussian

# %%
ent.set_train_options(
    convergence_mode = "fast", 
    dropR2 = 0.001, 
    gpu_mode = True, 
    seed = 1
)

ent.build()

ent.run()

# Save the output
ent.save("tmp/mofa_model.hdf5")
# Out:
# GPU mode is activated, but GPU not found... switching to CPU mode
# For GPU mode, you need:
# 1 - Make sure that you are running MOFA+ on a machine with an NVIDIA GPU
# 2 - Install CUPY following instructions on https://docs-cupy.chainer.org/en/stable/install.html
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -3181781.20
#
# Iteration 1: time=0.35, ELBO=-567016.11, deltaELBO=2614765.088 (82.17928657%), Factors=9
# Iteration 2: time=0.36, ELBO=-478387.33, deltaELBO=88628.777 (2.78550822%), Factors=8
# Iteration 3: time=0.33, ELBO=-470541.39, deltaELBO=7845.941 (0.24658959%), Factors=7
# Iteration 4: time=0.28, ELBO=-466294.22, deltaELBO=4247.174 (0.13348416%), Factors=6
# Iteration 5: time=0.31, ELBO=-463375.32, deltaELBO=2918.899 (0.09173791%), Factors=5
# Iteration 6: time=0.25, ELBO=-463041.02, deltaELBO=334.296 (0.01050656%), Factors=5
# Iteration 7: time=0.18, ELBO=-462888.35, deltaELBO=152.672 (0.00479833%), Factors=5
# Iteration 8: time=0.15, ELBO=-462789.83, deltaELBO=98.519 (0.00309636%), Factors=5
# Iteration 9: time=0.16, ELBO=-462708.44, deltaELBO=81.390 (0.00255799%), Factors=5
# Iteration 10: time=0.15, ELBO=-462633.40, deltaELBO=75.042 (0.00235850%), Factors=5
# Iteration 11: time=0.14, ELBO=-462561.75, deltaELBO=71.650 (0.00225190%), Factors=5
# Iteration 12: time=0.19, ELBO=-462493.01, deltaELBO=68.738 (0.00216036%), Factors=5
# Iteration 13: time=0.22, ELBO=-462427.11, deltaELBO=65.899 (0.00207115%), Factors=5
# Iteration 14: time=0.20, ELBO=-462363.80, deltaELBO=63.312 (0.00198982%), Factors=5
# Iteration 15: time=0.26, ELBO=-462302.69, deltaELBO=61.113 (0.00192071%), Factors=5
# Iteration 16: time=0.19, ELBO=-462243.43, deltaELBO=59.256 (0.00186235%), Factors=5
# Iteration 17: time=0.26, ELBO=-462185.84, deltaELBO=57.586 (0.00180986%), Factors=5
# Iteration 18: time=0.17, ELBO=-462129.88, deltaELBO=55.960 (0.00175877%), Factors=5
# Iteration 19: time=0.18, ELBO=-462075.61, deltaELBO=54.278 (0.00170591%), Factors=5
# Iteration 20: time=0.25, ELBO=-462023.08, deltaELBO=52.526 (0.00165083%), Factors=5
# Iteration 21: time=0.18, ELBO=-461972.28, deltaELBO=50.796 (0.00159645%), Factors=5
# Iteration 22: time=0.17, ELBO=-461923.11, deltaELBO=49.173 (0.00154544%), Factors=5
# Iteration 23: time=0.24, ELBO=-461875.43, deltaELBO=47.680 (0.00149853%), Factors=5
# Iteration 24: time=0.21, ELBO=-461829.07, deltaELBO=46.358 (0.00145697%), Factors=5
# Iteration 25: time=0.18, ELBO=-461783.82, deltaELBO=45.256 (0.00142235%), Factors=5
# Iteration 26: time=0.18, ELBO=-461739.42, deltaELBO=44.401 (0.00139549%), Factors=5
# Iteration 27: time=0.18, ELBO=-461695.62, deltaELBO=43.794 (0.00137640%), Factors=5
# Iteration 28: time=0.21, ELBO=-461652.22, deltaELBO=43.406 (0.00136419%), Factors=5
# Iteration 29: time=0.20, ELBO=-461609.04, deltaELBO=43.182 (0.00135716%), Factors=5
# Iteration 30: time=0.24, ELBO=-461565.98, deltaELBO=43.055 (0.00135316%), Factors=5
# Iteration 31: time=0.21, ELBO=-461523.03, deltaELBO=42.951 (0.00134991%), Factors=5
# Iteration 32: time=0.19, ELBO=-461480.24, deltaELBO=42.791 (0.00134488%), Factors=5
# Iteration 33: time=0.21, ELBO=-461437.73, deltaELBO=42.510 (0.00133604%), Factors=5
# Iteration 34: time=0.24, ELBO=-461395.62, deltaELBO=42.106 (0.00132334%), Factors=5
# Iteration 35: time=0.20, ELBO=-461353.99, deltaELBO=41.630 (0.00130840%), Factors=5
# Iteration 36: time=0.16, ELBO=-461312.85, deltaELBO=41.147 (0.00129321%), Factors=5
# Iteration 37: time=0.15, ELBO=-461272.14, deltaELBO=40.708 (0.00127940%), Factors=5
# Iteration 38: time=0.16, ELBO=-461231.79, deltaELBO=40.348 (0.00126810%), Factors=5
# Iteration 39: time=0.16, ELBO=-461191.70, deltaELBO=40.087 (0.00125989%), Factors=5
# Iteration 40: time=0.17, ELBO=-461151.78, deltaELBO=39.925 (0.00125480%), Factors=5
# Iteration 41: time=0.17, ELBO=-461111.93, deltaELBO=39.851 (0.00125247%), Factors=5
# Iteration 42: time=0.16, ELBO=-461072.08, deltaELBO=39.844 (0.00125227%), Factors=5
# Iteration 43: time=0.15, ELBO=-461032.20, deltaELBO=39.887 (0.00125361%), Factors=5
# Iteration 44: time=0.18, ELBO=-460992.22, deltaELBO=39.975 (0.00125636%), Factors=5
# Iteration 45: time=0.36, ELBO=-460952.09, deltaELBO=40.127 (0.00126115%), Factors=5
# Iteration 46: time=0.19, ELBO=-460911.71, deltaELBO=40.387 (0.00126932%), Factors=5
# Iteration 47: time=0.19, ELBO=-460870.88, deltaELBO=40.826 (0.00128311%), Factors=5
# Iteration 48: time=0.19, ELBO=-460829.34, deltaELBO=41.542 (0.00130561%), Factors=5
# Iteration 49: time=0.17, ELBO=-460786.72, deltaELBO=42.621 (0.00133955%), Factors=5
# Iteration 50: time=0.14, ELBO=-456461.92, deltaELBO=4324.801 (0.13592389%), Factors=5
# Iteration 51: time=0.18, ELBO=-456092.10, deltaELBO=369.821 (0.01162307%), Factors=5
# Iteration 52: time=0.18, ELBO=-455970.19, deltaELBO=121.904 (0.00383132%), Factors=5
# Iteration 53: time=0.18, ELBO=-455906.37, deltaELBO=63.826 (0.00200599%), Factors=5
# Iteration 54: time=0.14, ELBO=-455861.25, deltaELBO=45.119 (0.00141804%), Factors=5
# Iteration 55: time=0.29, ELBO=-455822.43, deltaELBO=38.819 (0.00122004%), Factors=5
# Iteration 56: time=0.38, ELBO=-455785.43, deltaELBO=36.996 (0.00116273%), Factors=5
# Iteration 57: time=0.21, ELBO=-455748.32, deltaELBO=37.110 (0.00116633%), Factors=5
# Iteration 58: time=0.47, ELBO=-455710.11, deltaELBO=38.211 (0.00120092%), Factors=5
# Iteration 59: time=0.35, ELBO=-455670.46, deltaELBO=39.656 (0.00124633%), Factors=5
# Iteration 60: time=0.18, ELBO=-455629.39, deltaELBO=41.069 (0.00129076%), Factors=5
# Iteration 61: time=0.19, ELBO=-455586.85, deltaELBO=42.540 (0.00133700%), Factors=5
# Iteration 62: time=0.17, ELBO=-455542.55, deltaELBO=44.297 (0.00139221%), Factors=5
# Iteration 63: time=0.16, ELBO=-455496.14, deltaELBO=46.412 (0.00145869%), Factors=5
# Iteration 64: time=0.15, ELBO=-455447.45, deltaELBO=48.688 (0.00153021%), Factors=5
# Iteration 65: time=0.15, ELBO=-455396.68, deltaELBO=50.773 (0.00159575%), Factors=5
# Iteration 66: time=0.15, ELBO=-455344.16, deltaELBO=52.519 (0.00165061%), Factors=5
# Iteration 67: time=0.14, ELBO=-455290.01, deltaELBO=54.143 (0.00170166%), Factors=5
# Iteration 68: time=0.15, ELBO=-455234.86, deltaELBO=55.153 (0.00173339%), Factors=5
# Iteration 69: time=0.16, ELBO=-455182.67, deltaELBO=52.196 (0.00164046%), Factors=5
# Iteration 70: time=0.17, ELBO=-455138.92, deltaELBO=43.750 (0.00137502%), Factors=5
# Iteration 71: time=0.18, ELBO=-455104.91, deltaELBO=34.010 (0.00106889%), Factors=5
# Iteration 72: time=0.16, ELBO=-455078.44, deltaELBO=26.468 (0.00083186%), Factors=5
# Iteration 73: time=0.15, ELBO=-455056.75, deltaELBO=21.688 (0.00068165%), Factors=5
# Iteration 74: time=0.15, ELBO=-455037.70, deltaELBO=19.046 (0.00059858%), Factors=5
# Iteration 75: time=0.15, ELBO=-455019.99, deltaELBO=17.709 (0.00055659%), Factors=5
# Iteration 76: time=0.19, ELBO=-455002.95, deltaELBO=17.047 (0.00053578%), Factors=5
# Iteration 77: time=0.14, ELBO=-454986.26, deltaELBO=16.692 (0.00052460%), Factors=5
# Iteration 78: time=0.16, ELBO=-454969.79, deltaELBO=16.461 (0.00051735%), Factors=5
# Iteration 79: time=0.12, ELBO=-454953.52, deltaELBO=16.275 (0.00051150%), Factors=5
# Iteration 80: time=0.12, ELBO=-454937.42, deltaELBO=16.102 (0.00050607%), Factors=5
# Iteration 81: time=0.14, ELBO=-454921.49, deltaELBO=15.932 (0.00050074%), Factors=5
# Iteration 82: time=0.12, ELBO=-454905.72, deltaELBO=15.764 (0.00049544%), Factors=5
# Iteration 83: time=0.13, ELBO=-454890.12, deltaELBO=15.597 (0.00049021%), Factors=5
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Saving model in tmp/mofa_model.hdf5...
